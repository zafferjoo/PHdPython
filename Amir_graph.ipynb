# %%
#pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path1.csv").Path
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve
pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path.csv").Path

def graph(x1,y1,x2,y2,div,name,count):
    print("Count is:",count)
    m,c,z = symbols('m,c,z')
    eq1 = Eq((x1*m+c),y1)
    print("Equation 1:")
    print(eq1)
    eq2 = Eq((x2*m+c), y2)
    print("Equation 2")
    print(eq2)
    Value=solve((eq1, eq2), (m,c))
    print("Slope:",Value[m])
    print("Intercept:",Value[c])
    Intercept=Value[c]
    slope=Value[m]
    vel1=(slope*0.0) +  Intercept
    vel2=(slope*2.4) +  Intercept
    vel3=(slope*4.8) +  Intercept
    vel4=(slope*7.2) +  Intercept
    vel5=(slope*9.6) +  Intercept
    vel6=(slope*12.0) +  Intercept
    vel7=(slope*14.5) +  Intercept
    vel8=(slope*16.9) +  Intercept
    vel9=(slope*19.3) +  Intercept
    vel10=(slope*22.8) +  Intercept
    vel11=(slope*25.2) +  Intercept
    vel12=(slope*27.6) +  Intercept
    vel13=(slope*29) +  Intercept
    
    if (count==0):
        x0=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y0=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case0="L Groyne Plain Water"
        print('case:',case0)
    if (count==1):
        x1=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y1=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case1="Normal Groyne Case 2"
        print('case:',case1)
    if (count==2):
        x2=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y2=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case2="Plain Water"
        print('case:',case2)
    if (count==3):
        x3=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y3=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case3="T Groyne Plain Water"
        print('case:',case3)
    if (count==4):
        x4=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y4=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case4="L135 Plain"
        print('case:',case4)
        plt.figure(figsize=(10,10))
        plt.xlabel('Width (cm)')
# naming the y axis
        plt.ylabel('Velocity for L Groyne Installed bed (m/s) ')
# giving a title to my graph
        title="Horizontal Velocity Distribution " + name
        plt.plot(x0, y0, label = case0,marker='.')
        plt.plot(x1, y1, label = case1,marker='.')
        plt.plot(x2, y2, label = case2,marker='.')
        plt.plot(x3, y3, label = case3,marker='.')
        plt.plot(x4, y4, label = case4,marker='.')
        plt.title(title)
        plt.grid()
        plt.show()
        
        
    
    
  
    
    


    
    
    
    
    
#pathinfo=pd.read_csv(r"D:/PhD Data AJ 2021 Onwards/ADV AMU/ADV AMU Jun 2022/New folder/Path.csv").Path
m=0
for paths in pathinfo:
    Temp=[]
    i=1
    my=[x for x in os.listdir(paths) if os.path.isdir(os.path.join(paths, x))] # List of folders in Each Path
    for f in my:    # Iterating via each folder
        path=paths + "\\" + f +"\\" #Getting the path of each folder
        mydata=os.listdir(path)
        csv_files = list(filter(lambda f: f.endswith('.csv'), mydata)) # Getting the list of csv files in each end folder
        for csv in csv_files:
            csv=path +csv
            #print(csv)
            vel=pd.read_csv(csv)
            corrected_velocity=vel["Corrected Velocity.X (m/s)"].mean()
            corrected_velocity=corrected_velocity *100
            Distance=(csv.split(".")[0]).split("_")[1]
            v='V' + f +'(at' +Distance +')'
            if Distance =='15' and v=='V11A1(at15)':
                Distance="14.5"
                v1=corrected_velocity
                x1=14.5
            if Distance =='21' and v=='V11A1(at21)':
                Distance="21.75"
            if Distance =='27' and v=='V11A1(at27)':
                Distance="29"
                v2=corrected_velocity
                x2=29
                div=7.25
                name='11A1'
                print('M:',m)
                graph(x1,v1,x2,v2,div,name,m)
                m=m+1
            if Distance =='15' and v=='V15A1(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15A1(at21)':
                Distance="23.25"
            if Distance =='27' and v=='V15A1(at27)':
                Distance="31"
            if Distance =='15' and v=='V19A1(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19A1(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19A1(at27)':
                Distance="33"
            if Distance =='15' and v=='V11A2(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11A2(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11A2(at27)':
                Distance="29"
            if Distance =='15' and v=='V15A2(at15)':
                Distance="15."
            if Distance =='21' and v=='V15A2(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15A2(at27)':
                Distance="31"
            if Distance =='15' and v=='V19A2(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19A2(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19A2(at27)':
                Distance="33"
            if Distance =='15' and v=='V11A3(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11A3(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11A3(at27)':
                Distance="29"
            if Distance =='15' and v=='V15A3(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15A3(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15A3(at27)':
                Distance="31"
            if Distance =='15' and v=='V19A3(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19A3(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19A3(at27)':
                Distance="33"
            if Distance =='15' and v=='V11A4(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11A4(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11A4(at27)':
                Distance="29"
            if Distance =='15' and v=='V15A4(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15A4(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15A4(at27)':
                Distance="31"
            if Distance =='15' and v=='V19A4(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19A4(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19A4(at27)':
                Distance="33"
            if Distance =='15' and v=='V11B1(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11B1(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11B1(at27)':
                Distance="29"
            if Distance =='15' and v=='V15B1(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15B1(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15B1(at27)':
                Distance="31"
            if Distance =='15' and v=='V19B1(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19B1(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19B1(at27)':
                Distance="33"
            if Distance =='15' and v=='V11B2(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11B2(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11B2(at27)':
                Distance="29"
            if Distance =='15' and v=='V15B2(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15B2(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15B2(at27)':
                Distance="31"
            if Distance =='15' and v=='V19B2(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19B2(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19B2(at27)':
                Distance="33"
            if Distance =='15' and v=='V11B3(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11B3(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11B3(at27)':
                Distance="29"
            if Distance =='15' and v=='V15B3(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15B3(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15B3(at27)':
                Distance="31"
            if Distance =='15' and v=='V19B3(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19B3(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19B3(at27)':
                Distance="33"
            if Distance =='15' and v=='V11B4(at15)':
                Distance="14.5"
            if Distance =='21' and v=='V11B4(at21)':
                Distance="22.75"
            if Distance =='27' and v=='V11B4(at27)':
                Distance="29"
            if Distance =='15' and v=='V15B4(at15)':
                Distance="15.5"
            if Distance =='21' and v=='V15B4(at21)':
                Distance="23.75"
            if Distance =='27' and v=='V15B4(at27)':
                Distance="31"
            if Distance =='15' and v=='V19B4(at15)':
                Distance="16.5"
            if Distance =='21' and v=='V19B4(at21)':
                Distance="24.75"
            if Distance =='27' and v=='V19B4(at27)':
                Distance="33"
            avgvelocity=0.6*corrected_velocity
            Depth=.22
            bead_shear_stress=1000*9.81*Depth*.0011
            shear_velocity=(bead_shear_stress/1000)**(.5)
            frno=corrected_velocity/(math.sqrt(9.81*.185))
            rnno=((4*avgvelocity*.093)/(.000001))
            xx=[[i,Depth,v,'%.3f' % corrected_velocity,Distance,'%.3f' % avgvelocity,'%.3f' % bead_shear_stress,'%.3f' % shear_velocity,'%.3f' %frno,'%.2f' %rnno]]
            y=["S. No","Depth of Flow (m)","Velocity Component","Velocity of Water (m/s) Computed by  ADV Flow Tracker","Distance along the width of flume (cm)","Average Velocity (U) (m/s)","Bed Shear Stress (N/m2)","Shear Velocity (m/s)","Froude Number","Reynolds Number"]
            table=pd.DataFrame(xx,columns=y)
            i=i+1
            Temp.append(table)
            Temp_table=pd.concat(Temp)
            #print(path)
            ta=Temp_table
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A1(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A1(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A1(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A1(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A1(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A1(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A1(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A1(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A1(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A2(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A2(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A2(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A2(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A2(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A2(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A2(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A2(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A2(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A3(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A3(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A3(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A3(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A3(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A3(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A3(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A3(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A3(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A4(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A4(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11A4(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A4(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A4(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15A4(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A4(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A4(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19A4(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B1(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B1(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B1(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B1(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B1(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B1(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B1(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B1(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B1(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B2(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B2(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B2(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B2(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B2(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B2(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B2(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B2(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B2(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B3(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B3(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B3(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B3(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B3(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B3(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B3(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B3(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B3(at27)","Velocity Component"]="V19(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B4(at15)","Velocity Component"]="V11(c)"  
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B4(at21)","Velocity Component"]="V11(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V11B4(at27)","Velocity Component"]="V11(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B4(at15)","Velocity Component"]="V15(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B4(at21)","Velocity Component"]="V15(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V15B4(at27)","Velocity Component"]="V15(rb)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B4(at15)","Velocity Component"]="V19(c)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B4(at21)","Velocity Component"]="V19(.75w)"
            Temp_table.loc[Temp_table["Velocity Component"]=="V19B4(at27)","Velocity Component"]="V19(rb)"
            #print(path)
        fs=paths+ "/" "Data Analysis.xlsx"
        Temp_table.to_excel(fs)
        fs=paths+ "/" "Data Analysis.csv"
        Temp_table.to_csv(fs)
# Out:
# M: 0
# Count is: 0
# Equation 1:
# Eq(c + 14.5*m, 8.32637362637363)
# Equation 2
# Eq(c + 29*m, 20.3512195121951)
# Slope: 0.829299716263550
# Intercept: -3.69847225944784
# case: L Groyne Plain Water
# M: 1
# Count is: 1
# Equation 1:
# Eq(c + 14.5*m, 7.94754098387097)
# Equation 2
# Eq(c + 29*m, 15.0688524590164)
# Slope: 0.491124929320374
# Intercept: 0.826229508725540
# case: Normal Groyne Case 2
# M: 2
# Count is: 2
# Equation 1:
# Eq(c + 14.5*m, 7.94754098387097)
# Equation 2
# Eq(c + 29*m, 27.1870588235294)
# Slope: 1.32686329928679
# Intercept: -11.2919768557875
# case: Plain Water
# M: 3
# Count is: 3
# Equation 1:
# Eq(c + 14.5*m, 16.121686746988)
# Equation 2
# Eq(c + 29*m, 28.0407407407407)
# Slope: 0.822003723707083
# Intercept: 4.20263275323530
# case: T Groyne Plain Water

# %%
# importing library sympy
from sympy import symbols, Eq, solve
  
# defining symbols used in equations
# or unknown variables
m,c,z = symbols('m,c,z')
  
# defining equations
eq1 = Eq((14.5*m+c),16.2)
print("Equation 1:")
print(eq1)
eq2 = Eq((21.75*m+c), 22.81)
print("Equation 2")
print(eq2)

eq3 = Eq((29*m+c), 28.041)
print(eq3)

  
Value=solve((eq1, eq3), (m,c))
print("Slope:",Value[m])
print("Intercept:",Value[c])
# Out:
# Equation 1:
# Eq(c + 14.5*m, 16.2)
# Equation 2
# Eq(c + 21.75*m, 22.81)
# Eq(c + 29*m, 28.041)
# Slope: 0.816620689655172
# Intercept: 4.35900000000000

# %%
#pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path1.csv").Path
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve
pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path.csv").Path

def graph(xx1,yy1,xx2,yy2,div,name,count):
    print("Count is:",count)
    m,c,z = symbols('m,c,z')
    eq1 = Eq((xx1*m+c),yy1)
    print("Equation 1:")
    print(eq1)
    eq2 = Eq((xx2*m+c), yy2)
    print("Equation 2")
    print(eq2)
    Value=solve((eq1, eq2), (m,c))
    print("Slope:",Value[m])
    print("Intercept:",Value[c])
    Intercept=Value[c]
    slope=Value[m]
    vel1=(slope*0.0) +  Intercept
    vel2=(slope*2.4) +  Intercept
    vel3=(slope*4.8) +  Intercept
    vel4=(slope*7.2) +  Intercept
    vel5=(slope*9.6) +  Intercept
    vel6=(slope*12.0) +  Intercept
    vel7=(slope*14.5) +  Intercept
    vel8=(slope*16.9) +  Intercept
    vel9=(slope*19.3) +  Intercept
    vel10=(slope*22.8) +  Intercept
    vel11=(slope*25.2) +  Intercept
    vel12=(slope*27.6) +  Intercept
    vel13=(slope*29) +  Intercept
    
    if (count==0):
        global x0
        global y0
        global case0
        x0=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y0=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case0="L Groyne Plain Water"
        print('case:',case0)
    if (count==1):
        global x1
        global y1
        global case1
        x1=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y1=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case1="Normal Groyne Case 2"
        print('case:',case1)
    if (count==2):
        global x2
        global y2
        global case2
        x2=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y2=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case2="Plain Water"
        print('case:',case2)
    if (count==3):
        x3=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y3=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case3="T Groyne Plain Water"
        print('case:',case3)
        #print('case:',case4)
        plt.figure(figsize=(10,10))
        plt.xlabel('Width (cm) ------->')
        plt.ylabel('Velocity  (cm/s) --------> ')
        title="Horizontal Velocity Distribution " + name
        #print('XX0:',x0)
        plt.plot(x0, y0, label = case0,marker='.')
        plt.plot(x1, y1, label = case1,marker='.')
        plt.plot(x2, y2, label = case2,marker='.')
        plt.plot(x3, y3, label = case3,marker='.')
        #plt.plot(x4, y4, label = case4,marker='.')
        plt.title(title)
        plt.grid()
        plt.legend()
        plt.show()
    if (count==4):
        x4=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y4=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case4="L135 Plain"
        print('case:',case4)
        plt.figure(figsize=(10,10))
        plt.xlabel('Width (cm)')
# naming the y axis
        plt.ylabel('Velocity (m/s) --------> ')
# giving a title to my graph
        title="Horizontal Velocity Distribution " + name + " ------->"
        print(x0)
        plt.plot(x0, y0, label = case0,marker='.')
        plt.plot(x1, y1, label = case1,marker='.')
        plt.plot(x2, y2, label = case2,marker='.')
        plt.plot(x3, y3, label = case3,marker='.')
        plt.plot(x4, y4, label = case4,marker='.')
        plt.title(title)
        plt.grid()
        plt.show()


m=0
for paths in pathinfo:
    Temp=[]
    i=1
    my=[x for x in os.listdir(paths) if os.path.isdir(os.path.join(paths, x))] # List of folders in Each Path
    for f in my:    # Iterating via each folder
        path=paths + "\\" + f +"\\" #Getting the path of each folder
        mydata=os.listdir(path)
        csv_files = list(filter(lambda f: f.endswith('.csv'), mydata)) # Getting the list of csv files in each end folder
        for csv in csv_files:
            csv=path +csv
            #print(csv)
            vel=pd.read_csv(csv)
            corrected_velocity=vel["Corrected Velocity.X (m/s)"].mean()
            corrected_velocity=corrected_velocity *100
            Distance=(csv.split(".")[0]).split("_")[1]
            v='V' + f +'(at' +Distance +')'
            if Distance =='15' and v=='V11A1(at15)':
                Distance="14.5"
                v1=corrected_velocity
                xx1=14.5
            if Distance =='21' and v=='V11A1(at21)':
                Distance="21.75"
            if Distance =='27' and v=='V11A1(at27)':
                Distance="29"
                v2=corrected_velocity
                xx2=29
                div=7.25
                name='11A1'
                print('M:',m)
                graph(xx1,v1,xx2,v2,div,name,m)
                m=m+1
# Out:
# M: 0
# Count is: 0
# Equation 1:
# Eq(c + 14.5*m, 8.32637362637363)
# Equation 2
# Eq(c + 29*m, 20.3512195121951)
# Slope: 0.829299716263550
# Intercept: -3.69847225944784
# case: L Groyne Plain Water
# M: 1
# Count is: 1
# Equation 1:
# Eq(c + 14.5*m, 7.94754098387097)
# Equation 2
# Eq(c + 29*m, 15.0688524590164)
# Slope: 0.491124929320374
# Intercept: 0.826229508725540
# case: Normal Groyne Case 2
# M: 2
# Count is: 2
# Equation 1:
# Eq(c + 14.5*m, 7.94754098387097)
# Equation 2
# Eq(c + 29*m, 27.1870588235294)
# Slope: 1.32686329928679
# Intercept: -11.2919768557875
# case: Plain Water
# M: 3
# Count is: 3
# Equation 1:
# Eq(c + 14.5*m, 16.121686746988)
# Equation 2
# Eq(c + 29*m, 28.0407407407407)
# Slope: 0.822003723707083
# Intercept: 4.20263275323530
# case: T Groyne Plain Water

# %%
#pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path1.csv").Path
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve
pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path.csv").Path

def graph(xx1,yy1,xx2,yy2,div,name,count):
    #print("Count is:",count)
    m,c,z = symbols('m,c,z')
    eq1 = Eq((xx1*m+c),yy1)
    print("Equation 1:")
    print(eq1)
    eq2 = Eq((xx2*m+c), yy2)
    #print("Equation 2")
    #print(eq2)
    Value=solve((eq1, eq2), (m,c))
    print("Slope:",Value[m])
    print("Intercept:",Value[c])
    Intercept=Value[c]
    slope=Value[m]
    vel1=(slope*0.0) +  Intercept
    vel2=(slope*2.4) +  Intercept
    vel3=(slope*4.8) +  Intercept
    vel4=(slope*7.2) +  Intercept
    vel5=(slope*9.6) +  Intercept
    vel6=(slope*12.0) +  Intercept
    vel7=(slope*14.5) +  Intercept
    vel8=(slope*16.9) +  Intercept
    vel9=(slope*19.3) +  Intercept
    vel10=(slope*22.8) +  Intercept
    vel11=(slope*25.2) +  Intercept
    vel12=(slope*27.6) +  Intercept
    vel13=(slope*29) +  Intercept
    
    if (count==0):
        global x0
        global y0
        global case0
        x0=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y0=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case0="L Groyne Plain Water"
        #print('case:',case0)
    if (count==1):
        global x1
        global y1
        global case1
        x1=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y1=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case1="Normal Groyne Case 2"
        #print('case:',case1)
    if (count==2):
        global x2
        global y2
        global case2
        x2=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y2=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case2="Plain Water"
        #print('case:',case2)
    if (count==3):
        global x3
        global y3
        global case3
        x3=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y3=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case3="T Groyne Plain Water"
    if (count==4):
        x4=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        y4=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        case4="L135 Plain"
        print('case:',case4)
        plt.figure(figsize=(10,5))
        plt.xlabel('Width (cm)')
# naming the y axis
        plt.ylabel('Velocity (cm/s) --------> ')
# giving a title to my graph
        title="Horizontal Velocity Distribution " + name + " ------->"
        #print(x0)
        plt.plot(x0, y0, label = case0,marker='.')
        plt.plot(x1, y1, label = case1,marker='.')
        plt.plot(x2, y2, label = case2,marker='.')
        plt.plot(x3, y3, label = case3,marker='.')
        plt.plot(x4, y4, label = case4,marker='.')
        plt.title(title)
        plt.grid()
        plt.legend()
        plt.show()


m=0
for paths in pathinfo:
    Temp=[]
    i=0
    my=[x for x in os.listdir(paths) if os.path.isdir(os.path.join(paths, x))] # List of folders in Each Path
    for f in my:    # Iterating via each folder
        path=paths + "\\" + f +"\\" #Getting the path of each folder
        mydata=os.listdir(path)
        csv_files = list(filter(lambda f: f.endswith('.csv'), mydata)) # Getting the list of csv files in each end folder
        for csv in csv_files:
            csv=path +csv
            ##print(csv)
            vel=pd.read_csv(csv)
            corrected_velocity=vel["Corrected Velocity.X (m/s)"].mean()
            corrected_velocity=corrected_velocity *100
            Distance=(csv.split(".")[0]).split("_")[1]
            v='V' + f +'(at' +Distance +')'
            if Distance =='15':# and v=='V11A1(at15)':
                Distance="14.5"
                print('Distance:',Distance)
                v1=corrected_velocity
                xx1=14.5
            if Distance =='21':# and v=='V11A1(at21)':
                Distance ="21.75"
                print('Distance inn:',Distance)
            if Distance =='27':# and v=='V11A1(at27)':
                Distance="29"
                print('Distance:',Distance)
                v2=corrected_velocity
                xx2=29
                div=7.25
                name='11A1'
                #print('M:',m)
                graph(xx1,v1,xx2,v2,div,name,m)
                m=m+1
# Out:
# Distance: 14.5
# Distance inn: 21.75
# Distance: 29
# Equation 1:
# Eq(c + 14.5*m, 16.121686746988)
# Slope: 0.822003723707083
# Intercept: 4.20263275323530
# Distance: 14.5
# Distance inn: 21.75
# Distance: 29
# Equation 1:
# Eq(c + 14.5*m, 15.7841121495327)
# Slope: 0.864967187179566
# Intercept: 3.24208793542900
# Distance: 14.5
# Distance inn: 21.75
# Distance: 29
# Equation 1:
# Eq(c + 14.5*m, 17.6574712643678)
# Slope: 0.732451773355462
# Intercept: 7.03692055071360
# Distance: 14.5
# Distance inn: 21.75
# Distance: 29
# Equation 1:
# Eq(c + 14.5*m, 8.32637362637363)
# Slope: 0.829299716263550
# Intercept: -3.69847225944784
# Distance: 14.5
# Distance inn: 21.75
# Distance: 29
# Equation 1:
# Eq(c + 14.5*m, 7.54204545454546)
# Slope: 0.936776258639575
# Intercept: -6.04121029572838
# case: L135 Plain
# Distance: 14.5
# Distance inn: 21.75
# Distance: 29
# Equation 1:
# Eq(c + 14.5*m, 8.43333333333333)
# Slope: 0.857661615052343
# Intercept: -4.00276008492563
# Distance: 14.5
# ...

# %%
#pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path1.csv").Path
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve
pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path.csv").Path
csv_files = list(filter(lambda f: f.endswith('.csv'), pathinfo))
csv_files

def graph(slope,Intercept):
    vel1=(slope*0.0) +  Intercept
    vel2=(slope*2.4) +  Intercept
    vel3=(slope*4.8) +  Intercept
    vel4=(slope*7.2) +  Intercept
    vel5=(slope*9.6) +  Intercept
    vel6=(slope*12.0) +  Intercept
    vel7=(slope*14.5) +  Intercept
    vel8=(slope*16.9) +  Intercept
    vel9=(slope*19.3) +  Intercept
    vel10=(slope*22.8) +  Intercept
    vel11=(slope*25.2) +  Intercept
    vel12=(slope*27.6) +  Intercept
    vel13=(slope*29) +  Intercept
    x2=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
    y2=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
    plt.figure(figsize=(10,7))
    plt.xlabel('Width (cm)')
# naming the y axis
    plt.ylabel('Velocity (cm/s) --------> ')
# giving a title to my graph
    title="Horizontal Velocity Distribution " + name + " ------->"
        #print(x0)
    plt.plot(x2, y2, label = case2,marker='.')
    plt.title(title)
    plt.grid()
    plt.legend()
    plt.show()


m=0
for paths in pathinfo:
    Temp=[]
    i=0
    my=[x for x in os.listdir(paths) if os.path.isdir(os.path.join(paths, x))]
    print(my)
    for f in my:    # Iterating via each folder
        path=paths + "\\" + f +"\\" #Getting the path of each folder
        mydata=os.listdir(path)
        csv_files = list(filter(lambda f: f.endswith('.csv'), mydata)) # Getting the list of csv files in each end folder
        for csv in csv_files:
            csv=path +csv
            velocity=0
            count=0
            vel=pd.read_csv(csv)
            vels=vel["Corrected Velocity.X (m/s)"]
            for v in vels:
                count=count+1
                if(v < 0):
                    v=v*-1
                velocity=v +velocity
            print(csv)    
            corrected_velocity=velocity/count
            corrected_velocity=corrected_velocity *100
            Distance=(csv.split(".")[0]).split("_")[1]
            #print('Distance:',Distance)
            v='V' + f +'(at' +Distance +')'
            if Distance =='15':# and v=='V11A1(at15)':
                Distance="14.5"
                #print('Distance:',Distance)
                v1=corrected_velocity
                print('corrected_velocity:',v1)
                xx1=14.5
                print('Distance:',Distance)
            if Distance =='21':# and v=='V11A1(at21)':
                Distance ="21.75"
                print('Distance inn:',Distance)
            if Distance =='27':# and v=='V11A1(at27)':
                Distance="29"
                print('Distance:',Distance)
                v2=corrected_velocity
                print('corrected_velocity:',v2)
                xx2=29
                div=(v2-v1)/14.5
                c=v2-(div*29)
                name='11A1'
                print('div:',div)
                print('C:',c)
                graph(div,c)
                m=m+1
# Out:
# []

# %%
m=(16.20-27.18)/14.5

# %%
c=16.20-(14.5*m)

# %%
m
# Out:
# -0.7572413793103449

# %%
16.20+.75*14.5
# Out:
# 27.075

# %%
import os
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve

def graph(slope,Intercept,case):
    vel1=(slope*0.0) +  Intercept
    vel2=(slope*2.4) +  Intercept
    vel3=(slope*4.8) +  Intercept
    vel4=(slope*7.2) +  Intercept
    vel5=(slope*9.6) +  Intercept
    vel6=(slope*12.0) +  Intercept
    vel7=(slope*14.5) +  Intercept
    vel8=(slope*16.9) +  Intercept
    vel9=(slope*19.3) +  Intercept
    vel10=(slope*22.8) +  Intercept
    vel11=(slope*25.2) +  Intercept
    vel12=(slope*27.6) +  Intercept
    vel13=(slope*29) +  Intercept
    print('Case Study:',case)
    if(case=="L Groyne Plain Water"):
        global Lx1,Ly1
        Lx1=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        Ly1=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
    if(case=="L135 Plain"):
        global L135x,L135y
        L135x=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        L135y=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
    if(case=="Normal Groyne Case 2"):
        global N135x,N135y
        N135x=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        N135y=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
    if(case=="Plain Water"):
        global Px,Py
        Px=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        Py=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
    if(case=="T Groyne Plain Water"):
        global Tx,Ty
        Tx=[0,2.4,4.8,7.2,9.6,12.0,14.5,16.9,19.3,22.8,25.2,27.6,29]
        Ty=[vel1,vel2,vel3,vel4,vel5,vel6,vel7,vel8,vel9,vel10,vel11,vel12,vel13]
        
  

    



pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path.csv").Path
for p in pathinfo:
    m=p.split("/")
    i=0
    for n in m:
        i=i+1
        case=m[i-1][0:2]
    Casestudy=m[7]
        

    files=os.listdir(p)
    csv_files = list(filter(lambda f: f.endswith('.csv'), files))
    for f in csv_files:
        file=p+ "/" +f
        velocity=0
        vel=pd.read_csv(file)
        vels=vel["Corrected Velocity.X (m/s)"]
        count=0
        print("************************")
        for v in vels:
            count=count+1
            if(v < 0):
                v=v*-1
            velocity=v +velocity
                #print(v)
        print(count)    
        corrected_velocity=velocity/count
        corrected_velocity=corrected_velocity *100
        Distance=(f.split(".")[0]).split("_")[1]
        print(corrected_velocity)
        print('Distance:',Distance)
        if(Distance=='15'):
            v1=corrected_velocity
            print('v1',v1)
            print('Case:',case)
        if(Distance=='27'):
            v2=corrected_velocity
            print('v2',v2)
            print('Case:',case)
            Veldiff=(v2-v1)
            print('Veldiff',Veldiff)
            if(case=='11'):
                di=14.5
                x=29
            if(case=='15'):
                di=15.5
                x=31
            if(case=='19'):
                di=16.5
                x=33
            slope=Veldiff/di
            print('x:',x)
            print(f'Slope for  :',case,' is ',slope)
            intercept=v2-(slope*x)
            print("Intercept:",intercept)
            graph(slope,intercept,Casestudy)
# Out:
# ************************
# 82
# 0.018292682926829278
# Distance: 15
# v1 0.018292682926829278
# Case: 11
# ************************
# 81
# 36.997530864197515
# Distance: 21
# ************************
# 82
# 31.56585365853658
# Distance: 27
# v2 31.56585365853658
# Case: 11
# Veldiff 31.54756097560975
# x: 29
# Slope for  : 11  is  2.1756938603868794
# Intercept: -31.529268292682925
# Case Study: L Groyne Plain Water
# ************************
# 49
# 37.76122448979592
# Distance: 15A
# ************************
# 100
# 35.368999999999986
# Distance: 21
# ************************
# 84
# 27.888095238095232
# Distance: 27
# v2 27.888095238095232
# Case: 11
# Veldiff 27.869802555168402
# x: 29
# Slope for  : 11  is  1.9220553486323035
# Intercept: -27.85150987224157
# Case Study: L135 Plain
# ************************
# 61
# 47.04426229508196
# Distance: 15
# v1 47.04426229508196
# Case: 11
# ************************
# 60
# 37.47166666666665
# Distance: 21
# ************************
# 6
# ...

# %%
point=[]
plt.figure(figsize=(10,5))
plt.xlabel('Width (cm)')
plt.ylabel('Velocity (cm/s) --------> ')
title="Horizontal Velocity Distribution 11A5" + " ------->"
case0="L Groyne Plain Water"
case1="L135 Plain"
case2="Normal Groyne Case 2"
case3="Plain Water"
case4="T Groyne Plain Water"
plt.plot(Lx1, Ly1, label = case0,marker='.')
plt.plot(L135x, L135y, label = case1,marker='.')
plt.plot(N135x, N135y, label = case2,marker='.')
plt.plot(Px,Py , label = case3,marker='.')
plt.plot(Tx, Ty, label = case4,marker='.')
plt.title(title)
plt.grid()
plt.legend()
plt.show()

point[0:13]=case
ODI_runs = {'Width(cm)': ['0','2.4','4.8','7.2','9.6','12.0','14.5','16.9','19.3','22.8','25.2','27.6','29'], 
            'Velocity of L Groyne Plain Water (cm/s)': Ly1,
            'Velocity of L135 Plain (cm/s)': L135y,
            'Velocity of Normal Groyne Case 2 (cm/s)': N135y,
             'Velocity of Plain Water (cm/s)': Py,
             'Velocity of T Groyne Plain Water (cm/s)': Ty
            
            
            
             } 
df = pd.DataFrame(ODI_runs)  
  
# making a yellow border
df.style.set_table_styles([{'selector' : '',
                            'props' : [('border',
                                        '1px solid black')]}])
# Out:
# <style type="text/css">
# #T_2756f_  {
#   border: 1px solid black;
# }
# </style>
# <table id="T_2756f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Width(cm)</th>
#       <th class="col_heading level0 col1" >Velocity of L Groyne Plain Water (cm/s)</th>
#       <th class="col_heading level0 col2" >Velocity of L135 Plain (cm/s)</th>
#       <th class="col_heading level0 col3" >Velocity of Normal Groyne Case 2 (cm/s)</th>
#       <th class="col_heading level0 col4" >Velocity of Plain Water (cm/s)</th>
#       <th class="col_heading level0 col5" >Velocity of T Groyne Plain Water (cm/s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2756f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2756f_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2756f_row0_col1" class="data row0 col1" >-31.529268</td>
# ...

# %%
x="C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir/All Cases/Water Flow All Cases/L Groyne Plain Water/Merged/Merged A1/19A1"
r=x.split("/")
i=0
for x in r:
    i=i+1
print(x[0:2])
# Out:
# 19

# %%
pathinfo=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir 2/path.csv").Path

# %%
for path in pathinfo:
    m=path.split("/")
    #print(m)
    i=0
    for n in m:
        i=i+1
    print(m[i-1][0:2])
# Out:
# 11
# 15
# 19

# %%
pa="C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir/All Cases/Water Flow All Cases"
os.listdir(pa)
# Out:
# ['L Groyne Plain Water',
#  'L135 Plain',
#  'Normal Groyne Case 2',
#  'Plain Water',
#  'T Groyne Plain Water']

# %%
m[7]
# Out:
# 'L Groyne Plain Water'

# %%
pathinfo[0]
# Out:
# 'C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir/All Cases/Water Flow All Cases/L Groyne Plain Water/Merged/Merged A5/11A5'

# %%
X=pd.read_csv(r"C:/Users/ZAFFER HUSSAIN JOO/Desktop/Aamir/All Cases/Water Flow All Cases/L135 Plain/Merged/Merged A1/11A1/11A1_15.csv")

# %%
point=[]
plt.figure(figsize=(10,5))
plt.xlabel('Width (cm)')
plt.ylabel('Velocity (cm/s) --------> ')
title="Horizontal Velocity Distribution 11A5" + " ------->"
case0="L Groyne Plain Water"
case1="L135 Plain"
case2="Normal Groyne Case 2"
case3="Plain Water"
case4="T Groyne Plain Water"
plt.plot(Lx1, Ly1, label = case0,marker='.')
plt.plot(L135x, L135y, label = case1,marker='.')
plt.plot(N135x, N135y, label = case2,marker='.')
plt.plot(Px,Py , label = case3,marker='.')
plt.plot(Tx, Ty, label = case4,marker='.')
plt.title(title)
plt.grid()
plt.legend()
plt.show()

point[0:13]=case
ODI_runs = {'Width(cm)': ['0','2.4','4.8','7.2','9.6','12.0','14.5','16.9','19.3','22.8','25.2','27.6','29'], 
            'Velocity of L Groyne Plain Water (cm/s)': Ly1,
            'Velocity of L135 Plain (cm/s)': L135y,
            'Velocity of Normal Groyne Case 2 (cm/s)': N135y,
             'Velocity of Plain Water (cm/s)': Py,
             'Velocity of T Groyne Plain Water (cm/s)': Ty
            
            
            
             } 
df = pd.DataFrame(ODI_runs)  
  
# making a yellow border
df.style.set_table_styles([{'selector' : '',
                            'props' : [('border',
                                        '1px solid black')]}])
# Out:
# <style type="text/css">
# #T_08d0b_  {
#   border: 1px solid black;
# }
# </style>
# <table id="T_08d0b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Width(cm)</th>
#       <th class="col_heading level0 col1" >Velocity of L Groyne Plain Water (cm/s)</th>
#       <th class="col_heading level0 col2" >Velocity of L135 Plain (cm/s)</th>
#       <th class="col_heading level0 col3" >Velocity of Normal Groyne Case 2 (cm/s)</th>
#       <th class="col_heading level0 col4" >Velocity of Plain Water (cm/s)</th>
#       <th class="col_heading level0 col5" >Velocity of T Groyne Plain Water (cm/s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08d0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08d0b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_08d0b_row0_col1" class="data row0 col1" >-30.007688</td>
# ...

# %%
case
# Out:
# '11'

# %%
# import the module
import pandas as pd 
point=pathinfo[1].split("/")[10][2:4]
  
# create a DataFrame 
ODI_runs = {'Point':[point,point,point,point,point,point,point,point,point,point,point,point,point],
            'Width(cm)': ['0','2.4','4.8','7.2','9.6','12.0','14.5','16.9','19.3','22.8','25.2','27.6','29'], 
            'Velocity of L Groyne Plain Water (cm/s)': Ly1,
            'Velocity of L135 Plain (cm/s)': L135y,
            'Velocity of Normal Groyne Case 2 (cm/s)': N135y,
             'Velocity of Plain Water (cm/s)': Py,
             'Velocity of T Groyne Plain Water (cm/s)': Ty
            
            
            
             } 
df = pd.DataFrame(ODI_runs)  
  
# making a yellow border
df.style.set_table_styles([{'selector' : '',
                            'props' : [('border',
                                        '1px solid black')]}])
# Out:
# <style type="text/css">
# #T_16edb_  {
#   border: 1px solid black;
# }
# </style>
# <table id="T_16edb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Point</th>
#       <th class="col_heading level0 col1" >Width(cm)</th>
#       <th class="col_heading level0 col2" >Velocity of L Groyne Plain Water (cm/s)</th>
#       <th class="col_heading level0 col3" >Velocity of L135 Plain (cm/s)</th>
#       <th class="col_heading level0 col4" >Velocity of Normal Groyne Case 2 (cm/s)</th>
#       <th class="col_heading level0 col5" >Velocity of Plain Water (cm/s)</th>
#       <th class="col_heading level0 col6" >Velocity of T Groyne Plain Water (cm/s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16edb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16edb_row0_col0" class="data row0 col0" >B2</td>
#       <td id="T_16edb_row0_col1" class="data row0 col1" >0</td>
# ...

# %%
point=pathinfo[1].split("/")[10][2:4]
point
# Out:
# 'B2'

# %%
# Out:
#   Input In [336]
#     case[[0:13]]=point
#            ^
# SyntaxError: invalid syntax
